# %% [markdown]
# Universidad del valle de Guatemala<br>
# Data Science<br>
# Alexis Fernando Hengstenberg Chocooj<br>
# carné 17699

# %% [markdown]
# # <center> Proyecto 1
# ---

# %% [markdown]
# ## Objetivos
# - Investigación a fondo sobre los datos del de accidentes para obtener un mayor conocimiento acerca de estos.
# - Limpieza de los datos eliminando columnas innecesarias dejando únicamente las columnas y filas que sean esenciales para la investigación y que no tengan demasiados datos ignorados.
# - Generar recomendaciones para la optimización de la base de datos que se tiene sobre los accidentes.
#
# ## Variables
# - año ocurrido
# - número de correlativo
# - Día ocurrido
# - Hora ocurrida
# - Grupo de hora
# - Grupo de 5 horas
# - Mes ocurrido
# - Día semana ocurrido
# - Municipio ocurrido
# - Departamento ocurrido
# - Zona ocurrida
# - Sexo de la persona
# - Edad de la persona
# - Mayores a 80
# - Mayores de 60
# - Edades quincenales
# - Mayor o menor de edad
# - Tipo de vehículo
# - Marca del vehículo
# - Color del vehículo
# - Modelo del vehículo
# - Grupo de modelo de vehículo
# - Tipo de evento
# - Fallecidos o lesionados
# - Internado o no internado
#
# #Variables indispensables para los seguros
# - Fecha del accidente
# - Hora del accidente
# - Lado de la calle
# - Velocidad
# - Causa
# - Marca del vehículo
# - Tipo de vehículo
# - Modelo de vehículo
#
#
# #Mejoras sugeridas.
# - El estado de la carretera en donde se produjo el accidente puede ser un factor que provoque los accidentes.
# - Agregar latitud y longitud, eliminando así varias columnas como el municipio, el departamento, etc. Ya que se sabría la ubicación exacta del accidente.
# - El estado de ebriedad del conductor es indispensable ya que puede indispensable en algunos accidentes.
# - La velocidad a la que se produjo el accidente.
# - El tipo de carretera como recta, curva sin peralte, curva con peralte, entre otras.
# <br>
# <br>
#
# ---

# %% [markdown]
# Importamos panda.

# %%
import pandas as pd

# %% [markdown]
# importamos todos los archivos.
#
# Nota: tener los archivos necesarios para importar.

# %%
#datos del 2019
data2019 = pd.read_excel("./2019.xlsx" )
#datos del 2018
data2018 = pd.read_excel("./2018.xlsx" )
#datos del 2017
data2017 = pd.read_excel("./2017.xlsx" )
#datos del 2016
data2016 = pd.read_excel("./2016.xlsx" )

# %% [markdown]
# Nos encargamos de unir los todos los años en un solo archivo para la limpieza de datos.

# %%
#dataframe1
data1 = pd.DataFrame(data2019)
#DataFrame2
data2 =pd.DataFrame(data2018)
#dataframe3
data3 = pd.DataFrame(data2017)
#DataFrame4
data4 = pd.DataFrame(data2016)
#juntamos todas las datas unidas anteriormente
dataCompleta = pd.concat([data1,data2,data3,data4])

# %% [markdown]
# Verificamos la unión y vemos que unas columnas no están en el todos los archivos con lo que procedemos a eliminarlas.

# %%
#vemos las columnas y las comparamos
dataCompleta.columns
# Out:
# Index(['núm_corre', 'año_ocu', 'día_ocu', 'hora_ocu', 'g_hora', 'g_hora_5',
#        'mes_ocu', 'día_sem_ocu', 'depto_ocu', 'mupio_ocu', 'zona_ocu',
#        'sexo_per', 'edad_per', 'g_edad_80ymás', 'g_edad_60ymás',
#        'edad_quinquenales', 'mayor_menor', 'color_veh', 'modelo_veh',
#        'g_modelo_veh', 'tipo_eve', 'fall_les', 'tipo_veh', 'marca_veh',
#        'int_o_noint', 'área_geo_ocu'],
#       dtype='object')

# %%
#comparamos columnas para luego eliminar las que no utilicemos
data2019.columns
# Out:
# Index(['núm_corre', 'año_ocu', 'día_ocu', 'hora_ocu', 'g_hora', 'g_hora_5',
#        'mes_ocu', 'día_sem_ocu', 'depto_ocu', 'mupio_ocu', 'zona_ocu',
#        'sexo_per', 'edad_per', 'g_edad_80ymás', 'g_edad_60ymás',
#        'edad_quinquenales', 'mayor_menor', 'color_veh', 'modelo_veh',
#        'g_modelo_veh', 'tipo_eve', 'fall_les', 'tipo_veh', 'marca_veh',
#        'int_o_noint'],
#       dtype='object')

# %% [markdown]
# Visualización de los datos.

# %%
data2019
# Out:
#        núm_corre  año_ocu  día_ocu  ...  tipo_veh  marca_veh  int_o_noint
# 0              1     2019        1  ...         4         64            1
# 1              2     2019        1  ...         4          6            1
# 2              3     2019        1  ...         4          6            1
# 3              4     2019        1  ...         4         18            1
# 4              5     2019        1  ...         4         67            1
# ...          ...      ...      ...  ...       ...        ...          ...
# 10659      10660     2019       31  ...         2         69            1
# 10660      10661     2019       31  ...         4        999            2
# 10661      10662     2019       31  ...         4        999            2
# 10662      10663     2019       31  ...        99        999            2
# 10663      10664     2019       31  ...         4          6            1
#
# [10664 rows x 25 columns]

# %%
data2018
# Out:
#       núm_corre  año_ocu  día_ocu  ...  tipo_eve  fall_les  int_o_noint
# 0             1     2018        1  ...         2         2            1
# 1             2     2018        1  ...         1         2            1
# 2             3     2018        1  ...         2         1            2
# 3             4     2018        1  ...         2         2            1
# 4             5     2018        1  ...         2         1            2
# ...         ...      ...      ...  ...       ...       ...          ...
# 9402       9403     2018       31  ...         5         1            2
# 9403       9404     2018       31  ...         5         1            2
# 9404       9405     2018       31  ...         5         1            2
# 9405       9406     2018       31  ...         5         2            1
# 9406       9407     2018       31  ...         5         2            1
#
# [9407 rows x 25 columns]

# %%
data2017
# Out:
#       núm_corre  año_ocu  día_ocu  ...  tipo_eve  fall_les  int_o_noint
# 0             1     2017        1  ...         1         2            1
# 1             2     2017        1  ...         1         2            1
# 2             3     2017        1  ...         1         2            1
# 3             4     2017        1  ...         2         2            1
# 4             5     2017        1  ...         2         2            1
# ...         ...      ...      ...  ...       ...       ...          ...
# 8620       8621     2017       31  ...         5         2            1
# 8621       8622     2017       31  ...         5         2            1
# 8622       8623     2017       31  ...         5         2            1
# 8623       8624     2017       31  ...         5         2            1
# 8624       8625     2017       31  ...         5         2            1
#
# [8625 rows x 25 columns]

# %%
data2016
# Out:
#        núm_corre  día_ocu  año_ocu  ...  g_modelo_veh  fall_les  int_o_noint
# 0              1        1     2016  ...             6         2            1
# 1              2        1     2016  ...             6         2            1
# 2              3        1     2016  ...             6         2            2
# 3              4        1     2016  ...             6         2            2
# 4              5        1     2016  ...             6         2            1
# ...          ...      ...      ...  ...           ...       ...          ...
# 11663      11664       31     2016  ...             6         2            1
# 11664      11665       31     2016  ...             6         2            2
# 11665      11666       31     2016  ...             6         1            2
# 11666      11667       31     2016  ...             6         1            2
# 11667      11668       31     2016  ...             4         2            1
#
# [11668 rows x 26 columns]

# %% [markdown]
# Eliminamos las columnas que no están en todos los años y las que no tienen referencia alguna con el diccionario, con lo cual es imposible obtener información de la columna.

# %%
#eliminalos la columna de area_geoocu ya que solo se utilizó en el año 2016 y eliminamos marca_veh ya que no se sabe que marca es marca es en el diccionario.
dataCompleta = dataCompleta.drop(["área_geo_ocu","marca_veh"],axis=1)
data2019 = data2019.drop(["marca_veh"],axis=1)
data2018 = data2018.drop(["marca_veh"],axis=1)
data2017 = data2017.drop(["marca_veh"],axis=1)
data2016 = data2016.drop(["área_geo_ocu","marca_veh"],axis=1)

# %% [markdown]
# ### datos ignorados
# ---

# %% [markdown]
# Buscamos en todas las columnas cuantos valores ignorados existen, ya que si son mas de la mitad no serviría para el análisis y se eliminara la columna.

# %%
#mes
data2019.mes_ocu.value_counts()
# Out:
# 4     1027
# 3     1017
# 12     993
# 5      938
# 1      922
# 9      917
# 2      869
# 6      859
# 8      847
# 11     817
# 7      768
# 10     690
# Name: mes_ocu, dtype: int64

# %%
#sexo de la persona
data2019.sexo_per.value_counts()
# Out:
# 1    7434
# 2    3167
# 9      63
# Name: sexo_per, dtype: int64

# %%
#mayores o menores de edad
data2019.mayor_menor.value_counts()
# Out:
# 1    8826
# 2    1603
# 9     235
# Name: mayor_menor, dtype: int64

# %%
data2019.fall_les.value_counts()
# Out:
# 2    8903
# 1    1757
# 9       4
# Name: fall_les, dtype: int64

# %%
#mes
data2018.mes_ocu.value_counts()
# Out:
# 3     1110
# 12     958
# 1      832
# 9      829
# 11     783
# 7      765
# 8      725
# 2      718
# 6      687
# 5      677
# 4      667
# 10     656
# Name: mes_ocu, dtype: int64

# %%
#sexo de la persona
data2018.sexo_per.value_counts()
# Out:
# 1    6667
# 2    2730
# 9      10
# Name: sexo_per, dtype: int64

# %%
#mayores o menores de edad
data2018.mayor_menor.value_counts()
# Out:
# 1    7871
# 2    1441
# 9      95
# Name: mayor_menor, dtype: int64

# %%
data2018.fall_les.value_counts()
# Out:
# 2    7938
# 1    1469
# Name: fall_les, dtype: int64

# %%
#mes
data2017.mes_ocu.value_counts()
# Out:
# 4     1006
# 12     894
# 7      802
# 11     744
# 1      682
# 10     679
# 9      672
# 5      668
# 6      663
# 2      653
# 3      622
# 8      540
# Name: mes_ocu, dtype: int64

# %%
#sexo de la persona
data2017.sexo_per.value_counts()
# Out:
# 1    6180
# 2    2431
# 9      14
# Name: sexo_per, dtype: int64

# %%
#mayores o menores de edad
data2017.mayor_menor.value_counts()
# Out:
# 1    7244
# 2    1367
# 9      14
# Name: mayor_menor, dtype: int64

# %%
data2017.fall_les.value_counts()
# Out:
# 2    7145
# 1    1480
# Name: fall_les, dtype: int64

# %%
#mes
data2016.mes_ocu.value_counts()
# Out:
# 3     1242
# 5     1123
# 12    1084
# 10     978
# 2      959
# 9      959
# 11     953
# 4      910
# 7      909
# 1      895
# 8      872
# 6      784
# Name: mes_ocu, dtype: int64

# %%
#sexo de la persona
data2016.sexo_per.value_counts()
# Out:
# 1    8140
# 2    3505
# 9      23
# Name: sexo_per, dtype: int64

# %%
#mayores o menores de edad
data2016.mayor_menor.value_counts()
# Out:
# 1    9632
# 2    1835
# 9     201
# Name: mayor_menor, dtype: int64

# %%
data2016.fall_les.value_counts()
# Out:
# 2    9660
# 1    2008
# Name: fall_les, dtype: int64

# %%
data2019.modelo_veh.value_counts()
# Out:
# 9999    7964
# 2018     299
# 2017     195
# 2016     180
# 2019     163
# 2015     110
# 2007     108
# 2012     107
# 2013      99
# 2014      94
# 2008      83
# 2003      82
# 1997      77
# 2006      71
# 2001      70
# 2011      67
# 2002      64
# 1996      64
# 2010      62
# 1993      60
# 1988      60
# 2000      58
# 2005      54
# 1995      53
# 2004      49
# 1999      44
# 1994      42
# 2009      39
# 1998      38
# 1991      34
# 1989      31
# 1987      29
# 1990      21
# 1992      20
# 1984      15
# 2020      15
# 1981      13
# 1986      12
# 1985      12
# 1975       2
# 1980       1
# 1982       1
# 1983       1
# 1976       1
# Name: modelo_veh, dtype: int64

# %%
data2018.modelo_veh.value_counts()
# Out:
# 9999    6515
# 2017     285
# 2016     264
# 2018     229
# 2015     164
# 2007     119
# 2012     117
# 2013     115
# 2006     103
# 2014      98
# 2003      91
# 2005      91
# 2001      81
# 2000      78
# 2008      77
# 2009      76
# 2002      74
# 2011      70
# 1995      58
# 1986      52
# 2004      48
# 1989      47
# 2010      47
# 1998      46
# 1994      44
# 1987      44
# 1991      42
# 1992      37
# 1997      36
# 1999      35
# 1993      35
# 1996      27
# 1990      24
# 1984      23
# 1980      23
# 1988      22
# 1985      14
# 2019      12
# 1965      11
# 1983      11
# 1979       9
# 1977       5
# 1974       3
# 1981       2
# 1978       1
# 1973       1
# 1975       1
# Name: modelo_veh, dtype: int64

# %%
data2017.modelo_veh.value_counts()
# Out:
# 9999    6150
# 2016     219
# 2017     197
# 2015     153
# 2014     118
# 2013     118
# 2007     108
# 2008     100
# 2012      96
# 2003      93
# 1999      81
# 1995      77
# 1998      74
# 2002      71
# 2004      70
# 2011      61
# 2010      60
# 2005      60
# 2009      59
# 2006      58
# 2001      52
# 1990      49
# 2000      48
# 1985      46
# 1987      46
# 1994      45
# 1993      43
# 1992      37
# 1991      35
# 1989      34
# 1986      31
# 1997      29
# 1988      29
# 1996      22
# 2018      20
# 1982       8
# 1983       6
# 1984       6
# 1978       4
# 1979       4
# 1980       3
# 1981       2
# 1938       1
# 1898       1
# 1971       1
# Name: modelo_veh, dtype: int64

# %%
data2016.modelo_veh.value_counts()
# Out:
# 9999    8693
# 2016     228
# 2015     222
# 2013     178
# 2012     171
# 2014     170
# 2006     139
# 2007     126
# 2005     107
# 2009      99
# 2008      98
# 1993      90
# 2004      86
# 2003      84
# 2000      79
# 2001      77
# 1994      75
# 2011      72
# 1999      72
# 1995      68
# 1996      68
# 1997      67
# 2010      62
# 2002      56
# 1985      56
# 1987      49
# 1992      46
# 1991      45
# 1990      44
# 1988      40
# 1998      35
# 1989      31
# 1984      27
# 1986      25
# 1983      21
# 2017      18
# 1981      18
# 1978       7
# 1982       7
# 1980       6
# 1977       2
# 1964       1
# 1965       1
# 1975       1
# 1976       1
# Name: modelo_veh, dtype: int64

# %% [markdown]
# Observamos que el modelo del vehículo en su mayoría es ignorado, con lo cual se ha decidido eliminar la columna de los datos.

# %%
# eliminamos la columna innsesaria
dataCompleta = dataCompleta.drop(["modelo_veh"],axis=1)
data2019 = data2019.drop(["modelo_veh"],axis=1)
data2018 = data2018.drop(["modelo_veh"],axis=1)
data2017 = data2017.drop(["modelo_veh"],axis=1)
data2016 = data2016.drop(["modelo_veh"],axis=1)

# %% [markdown]
# Mostramos la data completa y limpia

# %%
dataCompleta
# Out:
#        núm_corre  año_ocu  día_ocu  ...  fall_les  tipo_veh  int_o_noint
# 0              1     2019        1  ...         2         4            1
# 1              2     2019        1  ...         2         4            1
# 2              3     2019        1  ...         2         4            1
# 3              4     2019        1  ...         2         4            1
# 4              5     2019        1  ...         2         4            1
# ...          ...      ...      ...  ...       ...       ...          ...
# 11663      11664     2016       31  ...         2         4            1
# 11664      11665     2016       31  ...         2         3            2
# 11665      11666     2016       31  ...         1        99            2
# 11666      11667     2016       31  ...         1        99            2
# 11667      11668     2016       31  ...         2         4            1
#
# [40364 rows x 23 columns]
